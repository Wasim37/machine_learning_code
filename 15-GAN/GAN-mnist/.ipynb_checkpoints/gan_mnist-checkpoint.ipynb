# %% [markdown]
# ## 对抗生成网络案例 ##
#
#
# <img src="jpg/3.png" alt="FAO" width="590" >

# %% [markdown]
# - 判别器 : 火眼金睛，分辨出生成和真实的 <br />
# <br />
# - 生成器 : 瞒天过海，骗过判别器 <br />
# <br />
# - 损失函数定义 : 一方面要让判别器分辨能力更强，另一方面要让生成器更真 <br />
# <br />
#
# <img src="jpg/1.jpg" alt="FAO" width="590" >

# %%
import tensorflow as tf
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # 导入数据

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('/mnist')

# %% [markdown]
# ## 网络架构
#
# ### 输入层 ：待生成图像（噪音）和真实数据
#
# ### 生成网络：将噪音图像进行生成
#
# ### 判别网络：
# - （1）判断真实图像输出结果
# - （2）判断生成图像输出结果
#
# ### 目标函数：
# - （1）对于生成网络要使得生成结果通过判别网络为真
# - （2）对于判别网络要使得输入为真实图像时判别为真 输入为生成图像时判别为假
#
# <img src="jpg/2.png" alt="FAO" width="590" >

# %% [markdown]
# ## Inputs

# %%
#真实数据和噪音数据
def get_inputs(real_size, noise_size):
    
    real_img = tf.placeholder(tf.float32, [None, real_size])
    noise_img = tf.placeholder(tf.float32, [None, noise_size])
    
    return real_img, noise_img

# %% [markdown]
# ## 生成器
# * noise_img: 产生的噪音输入
# * n_units: 隐层单元个数
# * out_dim: 输出的大小（28 * 28 * 1）

# %%
def get_generator(noise_img, n_units, out_dim, reuse=False, alpha=0.01):
  
    with tf.variable_scope("generator", reuse=reuse):
        # hidden layer
        hidden1 = tf.layers.dense(noise_img, n_units)
        # leaky ReLU
        hidden1 = tf.maximum(alpha * hidden1, hidden1)
        # dropout
        hidden1 = tf.layers.dropout(hidden1, rate=0.2)

        # logits & outputs
        logits = tf.layers.dense(hidden1, out_dim)
        outputs = tf.tanh(logits)
        
        return logits, outputs

# %% [markdown]
# ## 判别器
# * img：输入
# * n_units：隐层单元数量
# * reuse：由于要使用两次

# %%
def get_discriminator(img, n_units, reuse=False, alpha=0.01):

    with tf.variable_scope("discriminator", reuse=reuse):
        # hidden layer
        hidden1 = tf.layers.dense(img, n_units)
        hidden1 = tf.maximum(alpha * hidden1, hidden1)
        
        # logits & outputs
        logits = tf.layers.dense(hidden1, 1)
        outputs = tf.sigmoid(logits)
        
        return logits, outputs

# %% [markdown]
# ## 网络参数定义
# * img_size：输入大小
# * noise_size：噪音图像大小
# * g_units：生成器隐层参数
# * d_units：判别器隐层参数
# * learning_rate：学习率

# %%
img_size = mnist.train.images[0].shape[0]

noise_size = 100

g_units = 128

d_units = 128

learning_rate = 0.001

alpha = 0.01

# %% [markdown]
# ## 构建网络

# %%
tf.reset_default_graph()

real_img, noise_img = get_inputs(img_size, noise_size)

# generator
g_logits, g_outputs = get_generator(noise_img, g_units, img_size)

# discriminator
d_logits_real, d_outputs_real = get_discriminator(real_img, d_units)
d_logits_fake, d_outputs_fake = get_discriminator(g_outputs, d_units, reuse=True)

# %% [markdown]
# ### 目标函数：
# - （1）对于生成网络要使得生成结果通过判别网络为真
# - （2）对于判别网络要使得输入为真实图像时判别为真 输入为生成图像时判别为假
#
# <img src="jpg/2.png" alt="FAO" width="590" >

# %%
# discriminator的loss
# 识别真实图片
d_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, 
                                                                     labels=tf.ones_like(d_logits_real)))
# 识别生成的图片
d_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, 
                                                                     labels=tf.zeros_like(d_logits_fake)))
# 总体loss
d_loss = tf.add(d_loss_real, d_loss_fake)

# generator的loss
g_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake,
                                                                labels=tf.ones_like(d_logits_fake)))

# %% [markdown]
# ## 优化器

# %%
train_vars = tf.trainable_variables()

# generator
g_vars = [var for var in train_vars if var.name.startswith("generator")]
# discriminator
d_vars = [var for var in train_vars if var.name.startswith("discriminator")]

# optimizer
d_train_opt = tf.train.AdamOptimizer(learning_rate).minimize(d_loss, var_list=d_vars)
g_train_opt = tf.train.AdamOptimizer(learning_rate).minimize(g_loss, var_list=g_vars)

# %% [markdown]
# # 训练

# %%
# batch_size
batch_size = 64
# 训练迭代轮数
epochs = 300
# 抽取样本数
n_sample = 25

# 存储测试样例
samples = []
# 存储loss
losses = []
# 保存生成器变量
saver = tf.train.Saver(var_list = g_vars)
# 开始训练
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for e in range(epochs):
        for batch_i in range(mnist.train.num_examples//batch_size):
            batch = mnist.train.next_batch(batch_size)
            
            batch_images = batch[0].reshape((batch_size, 784))
            # 对图像像素进行scale，这是因为tanh输出的结果介于(-1,1),real和fake图片共享discriminator的参数
            batch_images = batch_images*2 - 1
            
            # generator的输入噪声
            batch_noise = np.random.uniform(-1, 1, size=(batch_size, noise_size))
            
            # Run optimizers
            _ = sess.run(d_train_opt, feed_dict={real_img: batch_images, noise_img: batch_noise})
            _ = sess.run(g_train_opt, feed_dict={noise_img: batch_noise})
        
        # 每一轮结束计算loss
        train_loss_d = sess.run(d_loss, 
                                feed_dict = {real_img: batch_images, 
                                             noise_img: batch_noise})
        # real img loss
        train_loss_d_real = sess.run(d_loss_real, 
                                     feed_dict = {real_img: batch_images, 
                                                 noise_img: batch_noise})
        # fake img loss
        train_loss_d_fake = sess.run(d_loss_fake, 
                                    feed_dict = {real_img: batch_images, 
                                                 noise_img: batch_noise})
        # generator loss
        train_loss_g = sess.run(g_loss, 
                                feed_dict = {noise_img: batch_noise})
        
            
        print("Epoch {}/{}...".format(e+1, epochs),
              "判别器损失: {:.4f}(判别真实的: {:.4f} + 判别生成的: {:.4f})...".format(train_loss_d, train_loss_d_real, train_loss_d_fake),
              "生成器损失: {:.4f}".format(train_loss_g))    
        
        losses.append((train_loss_d, train_loss_d_real, train_loss_d_fake, train_loss_g))
        
        # 保存样本
        sample_noise = np.random.uniform(-1, 1, size=(n_sample, noise_size))
        gen_samples = sess.run(get_generator(noise_img, g_units, img_size, reuse=True),
                               feed_dict={noise_img: sample_noise})
        samples.append(gen_samples)
        
        
        saver.save(sess, './checkpoints/generator.ckpt')

# 保存到本地
with open('train_samples.pkl', 'wb') as f:
    pickle.dump(samples, f)
# Out:
# Epoch 1/300... 判别器损失: 0.0419(判别真实的: 0.0014 + 判别生成的: 0.0405)... 生成器损失: 3.8008
# Epoch 2/300... 判别器损失: 0.2536(判别真实的: 0.1991 + 判别生成的: 0.0544)... 生成器损失: 4.1958
# Epoch 3/300... 判别器损失: 0.8420(判别真实的: 0.3731 + 判别生成的: 0.4689)... 生成器损失: 6.2357
# Epoch 4/300... 判别器损失: 0.8232(判别真实的: 0.1771 + 判别生成的: 0.6461)... 生成器损失: 1.7907
# Epoch 5/300... 判别器损失: 1.2470(判别真实的: 0.7575 + 判别生成的: 0.4895)... 生成器损失: 2.9907
# Epoch 6/300... 判别器损失: 1.6540(判别真实的: 0.7277 + 判别生成的: 0.9263)... 生成器损失: 0.7700
# Epoch 7/300... 判别器损失: 1.8045(判别真实的: 0.9542 + 判别生成的: 0.8503)... 生成器损失: 1.5695
# Epoch 8/300... 判别器损失: 1.5491(判别真实的: 1.1568 + 判别生成的: 0.3923)... 生成器损失: 2.3933
# Epoch 9/300... 判别器损失: 1.4013(判别真实的: 0.4586 + 判别生成的: 0.9427)... 生成器损失: 1.5472
# Epoch 10/300... 判别器损失: 2.0657(判别真实的: 1.4063 + 判别生成的: 0.6594)... 生成器损失: 1.8785
# Epoch 11/300... 判别器损失: 1.0202(判别真实的: 0.6609 + 判别生成的: 0.3592)... 生成器损失: 3.4438
# Epoch 12/300... 判别器损失: 0.9237(判别真实的: 0.5010 + 判别生成的: 0.4227)... 生成器损失: 1.9403
# Epoch 13/300... 判别器损失: 1.2636(判别真实的: 0.8710 + 判别生成的: 0.3926)... 生成器损失: 1.8626
# Epoch 14/300... 判别器损失: 0.9335(判别真实的: 0.3992 + 判别生成的: 0.5343)... 生成器损失: 1.3328
# Epoch 15/300... 判别器损失: 1.1265(判别真实的: 0.5531 + 判别生成的: 0.5734)... 生成器损失: 1.2432
# Epoch 16/300... 判别器损失: 0.7616(判别真实的: 0.5133 + 判别生成的: 0.2483)... 生成器损失: 2.1370
# Epoch 17/300... 判别器损失: 0.8849(判别真实的: 0.5790 + 判别生成的: 0.3059)... 生成器损失: 1.8650
# Epoch 18/300... 判别器损失: 1.1413(判别真实的: 0.5334 + 判别生成的: 0.6078)... 生成器损失: 1.4118
# Epoch 19/300... 判别器损失: 1.0946(判别真实的: 0.6189 + 判别生成的: 0.4757)... 生成器损失: 1.5966
# Epoch 20/300... 判别器损失: 1.2510(判别真实的: 0.4917 + 判别生成的: 0.7592)... 生成器损失: 1.9188
# Epoch 21/300... 判别器损失: 0.8760(判别真实的: 0.4202 + 判别生成的: 0.4557)... 生成器损失: 2.4810
# Epoch 22/300... 判别器损失: 1.2002(判别真实的: 0.6616 + 判别生成的: 0.5386)... 生成器损失: 1.6671
# Epoch 23/300... 判别器损失: 1.2566(判别真实的: 0.7762 + 判别生成的: 0.4804)... 生成器损失: 1.8045
# Epoch 24/300... 判别器损失: 0.8259(判别真实的: 0.2870 + 判别生成的: 0.5388)... 生成器损失: 1.6449
# Epoch 25/300... 判别器损失: 1.0993(判别真实的: 0.4572 + 判别生成的: 0.6422)... 生成器损失: 1.1125
# Epoch 26/300... 判别器损失: 1.1784(判别真实的: 0.5548 + 判别生成的: 0.6236)... 生成器损失: 1.5359
# Epoch 27/300... 判别器损失: 0.5747(判别真实的: 0.3520 + 判别生成的: 0.2227)... 生成器损失: 2.6816
# Epoch 28/300... 判别器损失: 1.3060(判别真实的: 0.5233 + 判别生成的: 0.7827)... 生成器损失: 1.2598
# Epoch 29/300... 判别器损失: 1.0644(判别真实的: 0.5662 + 判别生成的: 0.4982)... 生成器损失: 1.7115
# Epoch 30/300... 判别器损失: 0.9492(判别真实的: 0.2734 + 判别生成的: 0.6758)... 生成器损失: 1.4510
# Epoch 31/300... 判别器损失: 1.2672(判别真实的: 0.6112 + 判别生成的: 0.6560)... 生成器损失: 1.5266
# Epoch 32/300... 判别器损失: 0.9111(判别真实的: 0.5523 + 判别生成的: 0.3588)... 生成器损失: 1.9988
# Epoch 33/300... 判别器损失: 0.9895(判别真实的: 0.4675 + 判别生成的: 0.5219)... 生成器损失: 1.3430
# Epoch 34/300... 判别器损失: 1.2390(判别真实的: 0.6314 + 判别生成的: 0.6076)... 生成器损失: 1.5232
# Epoch 35/300... 判别器损失: 0.7892(判别真实的: 0.4811 + 判别生成的: 0.3082)... 生成器损失: 2.2145
# Epoch 36/300... 判别器损失: 0.9179(判别真实的: 0.5275 + 判别生成的: 0.3904)... 生成器损失: 1.7120
# Epoch 37/300... 判别器损失: 0.9968(判别真实的: 0.3151 + 判别生成的: 0.6817)... 生成器损失: 1.3213
# Epoch 38/300... 判别器损失: 1.1112(判别真实的: 0.4072 + 判别生成的: 0.7040)... 生成器损失: 1.5076
# Epoch 39/300... 判别器损失: 0.8958(判别真实的: 0.3540 + 判别生成的: 0.5418)... 生成器损失: 1.2721
# Epoch 40/300... 判别器损失: 0.6345(判别真实的: 0.2926 + 判别生成的: 0.3419)... 生成器损失: 1.8206
# Epoch 41/300... 判别器损失: 0.9710(判别真实的: 0.5156 + 判别生成的: 0.4554)... 生成器损失: 1.7402
# Epoch 42/300... 判别器损失: 1.3950(判别真实的: 0.6269 + 判别生成的: 0.7681)... 生成器损失: 1.1483
# Epoch 43/300... 判别器损失: 0.8902(判别真实的: 0.3531 + 判别生成的: 0.5371)... 生成器损失: 1.7964
# Epoch 44/300... 判别器损失: 1.2611(判别真实的: 0.8299 + 判别生成的: 0.4313)... 生成器损失: 2.1427
# Epoch 45/300... 判别器损失: 0.8807(判别真实的: 0.5686 + 判别生成的: 0.3121)... 生成器损失: 1.9497
# Epoch 46/300... 判别器损失: 1.3379(判别真实的: 0.8090 + 判别生成的: 0.5288)... 生成器损失: 1.4330
# Epoch 47/300... 判别器损失: 1.2068(判别真实的: 0.8162 + 判别生成的: 0.3906)... 生成器损失: 1.6340
# Epoch 48/300... 判别器损失: 1.0360(判别真实的: 0.3343 + 判别生成的: 0.7018)... 生成器损失: 1.4151
# Epoch 49/300... 判别器损失: 0.7911(判别真实的: 0.3958 + 判别生成的: 0.3953)... 生成器损失: 1.8603
# Epoch 50/300... 判别器损失: 1.0163(判别真实的: 0.4335 + 判别生成的: 0.5828)... 生成器损失: 1.2897
# Epoch 51/300... 判别器损失: 0.8334(判别真实的: 0.2531 + 判别生成的: 0.5804)... 生成器损失: 1.4745
# Epoch 52/300... 判别器损失: 0.8384(判别真实的: 0.3381 + 判别生成的: 0.5003)... 生成器损失: 1.4708
# Epoch 53/300... 判别器损失: 0.9813(判别真实的: 0.5521 + 判别生成的: 0.4292)... 生成器损失: 1.6507
# Epoch 54/300... 判别器损失: 1.0183(判别真实的: 0.5657 + 判别生成的: 0.4526)... 生成器损失: 1.6843
# Epoch 55/300... 判别器损失: 0.9496(判别真实的: 0.4260 + 判别生成的: 0.5236)... 生成器损失: 1.4713
# Epoch 56/300... 判别器损失: 1.1383(判别真实的: 0.7591 + 判别生成的: 0.3792)... 生成器损失: 1.9197
# Epoch 57/300... 判别器损失: 1.1383(判别真实的: 0.5159 + 判别生成的: 0.6224)... 生成器损失: 1.0997
# Epoch 58/300... 判别器损失: 1.0903(判别真实的: 0.5402 + 判别生成的: 0.5502)... 生成器损失: 1.4597
# Epoch 59/300... 判别器损失: 0.9735(判别真实的: 0.5695 + 判别生成的: 0.4040)... 生成器损失: 1.6569
# Epoch 60/300... 判别器损失: 0.9931(判别真实的: 0.4902 + 判别生成的: 0.5029)... 生成器损失: 1.4635
# Epoch 61/300... 判别器损失: 0.8758(判别真实的: 0.4991 + 判别生成的: 0.3767)... 生成器损失: 1.7371
# Epoch 62/300... 判别器损失: 1.3442(判别真实的: 0.5792 + 判别生成的: 0.7650)... 生成器损失: 1.2243
# Epoch 63/300... 判别器损失: 1.0762(判别真实的: 0.3231 + 判别生成的: 0.7532)... 生成器损失: 1.1942
# Epoch 64/300... 判别器损失: 0.9772(判别真实的: 0.5583 + 判别生成的: 0.4190)... 生成器损失: 1.6193
# Epoch 65/300... 判别器损失: 0.9019(判别真实的: 0.4122 + 判别生成的: 0.4897)... 生成器损失: 1.6219
# Epoch 66/300... 判别器损失: 1.2156(判别真实的: 0.8971 + 判别生成的: 0.3185)... 生成器损失: 1.7879
# Epoch 67/300... 判别器损失: 0.8597(判别真实的: 0.4098 + 判别生成的: 0.4499)... 生成器损失: 1.7131
# Epoch 68/300... 判别器损失: 0.7782(判别真实的: 0.4989 + 判别生成的: 0.2793)... 生成器损失: 1.9302
# Epoch 69/300... 判别器损失: 0.8175(判别真实的: 0.4637 + 判别生成的: 0.3537)... 生成器损失: 1.9230
# Epoch 70/300... 判别器损失: 0.9629(判别真实的: 0.4334 + 判别生成的: 0.5295)... 生成器损失: 1.5045
# Epoch 71/300... 判别器损失: 0.9237(判别真实的: 0.4467 + 判别生成的: 0.4769)... 生成器损失: 1.6658
# Epoch 72/300... 判别器损失: 1.1775(判别真实的: 0.5805 + 判别生成的: 0.5971)... 生成器损失: 1.2036
# Epoch 73/300... 判别器损失: 1.1674(判别真实的: 0.6453 + 判别生成的: 0.5221)... 生成器损失: 1.3755
# Epoch 74/300... 判别器损失: 1.0604(判别真实的: 0.6555 + 判别生成的: 0.4050)... 生成器损失: 1.7645
# Epoch 75/300... 判别器损失: 0.9482(判别真实的: 0.4521 + 判别生成的: 0.4961)... 生成器损失: 1.5025
# Epoch 76/300... 判别器损失: 0.8502(判别真实的: 0.4963 + 判别生成的: 0.3538)... 生成器损失: 1.7529
# Epoch 77/300... 判别器损失: 1.1057(判别真实的: 0.4139 + 判别生成的: 0.6918)... 生成器损失: 1.1369
# Epoch 78/300... 判别器损失: 1.1340(判别真实的: 0.6315 + 判别生成的: 0.5025)... 生成器损失: 1.5046
# Epoch 79/300... 判别器损失: 1.1239(判别真实的: 0.5137 + 判别生成的: 0.6102)... 生成器损失: 1.3572
# Epoch 80/300... 判别器损失: 1.0110(判别真实的: 0.2795 + 判别生成的: 0.7316)... 生成器损失: 1.2132
# Epoch 81/300... 判别器损失: 0.9456(判别真实的: 0.4151 + 判别生成的: 0.5304)... 生成器损失: 1.3805
# Epoch 82/300... 判别器损失: 0.9237(判别真实的: 0.3815 + 判别生成的: 0.5422)... 生成器损失: 1.1627
# Epoch 83/300... 判别器损失: 1.1589(判别真实的: 0.6616 + 判别生成的: 0.4972)... 生成器损失: 1.5946
# Epoch 84/300... 判别器损失: 0.9080(判别真实的: 0.5134 + 判别生成的: 0.3946)... 生成器损失: 1.6184
# Epoch 85/300... 判别器损失: 0.7712(判别真实的: 0.4184 + 判别生成的: 0.3528)... 生成器损失: 1.6760
# Epoch 86/300... 判别器损失: 1.0406(判别真实的: 0.5070 + 判别生成的: 0.5337)... 生成器损失: 1.5527
# Epoch 87/300... 判别器损失: 1.1954(判别真实的: 0.7893 + 判别生成的: 0.4061)... 生成器损失: 1.6121
# Epoch 88/300... 判别器损失: 0.9895(判别真实的: 0.4779 + 判别生成的: 0.5116)... 生成器损失: 1.3649
# Epoch 89/300... 判别器损失: 1.1310(判别真实的: 0.4228 + 判别生成的: 0.7082)... 生成器损失: 1.1409
# Epoch 90/300... 判别器损失: 1.0749(判别真实的: 0.4267 + 判别生成的: 0.6482)... 生成器损失: 1.3140
# Epoch 91/300... 判别器损失: 1.0421(判别真实的: 0.6728 + 判别生成的: 0.3693)... 生成器损失: 1.6451
# Epoch 92/300... 判别器损失: 0.8404(判别真实的: 0.5295 + 判别生成的: 0.3109)... 生成器损失: 1.8519
# Epoch 93/300... 判别器损失: 0.9334(判别真实的: 0.5360 + 判别生成的: 0.3974)... 生成器损失: 1.5926
# Epoch 94/300... 判别器损失: 0.9736(判别真实的: 0.5134 + 判别生成的: 0.4602)... 生成器损失: 1.3918
# Epoch 95/300... 判别器损失: 1.0047(判别真实的: 0.5242 + 判别生成的: 0.4805)... 生成器损失: 1.3791
# Epoch 96/300... 判别器损失: 0.8896(判别真实的: 0.3668 + 判别生成的: 0.5228)... 生成器损失: 1.4503
# Epoch 97/300... 判别器损失: 0.8018(判别真实的: 0.3591 + 判别生成的: 0.4427)... 生成器损失: 1.5234
# Epoch 98/300... 判别器损失: 0.8572(判别真实的: 0.4527 + 判别生成的: 0.4046)... 生成器损失: 1.6963
# Epoch 99/300... 判别器损失: 1.1731(判别真实的: 0.5416 + 判别生成的: 0.6315)... 生成器损失: 1.2565
# Epoch 100/300... 判别器损失: 0.8191(判别真实的: 0.3834 + 判别生成的: 0.4357)... 生成器损失: 1.5883
# Epoch 101/300... 判别器损失: 1.2468(判别真实的: 0.6559 + 判别生成的: 0.5909)... 生成器损失: 1.1992
# Epoch 102/300... 判别器损失: 0.8786(判别真实的: 0.5608 + 判别生成的: 0.3178)... 生成器损失: 1.8691
# Epoch 103/300... 判别器损失: 0.9106(判别真实的: 0.5716 + 判别生成的: 0.3389)... 生成器损失: 1.8324
# Epoch 104/300... 判别器损失: 1.3186(判别真实的: 0.5978 + 判别生成的: 0.7208)... 生成器损失: 1.0781
# Epoch 105/300... 判别器损失: 0.8973(判别真实的: 0.4939 + 判别生成的: 0.4033)... 生成器损失: 1.7341
# Epoch 106/300... 判别器损失: 0.9410(判别真实的: 0.5584 + 判别生成的: 0.3825)... 生成器损失: 1.6251
# Epoch 107/300... 判别器损失: 0.9802(判别真实的: 0.3393 + 判别生成的: 0.6409)... 生成器损失: 1.2325
# Epoch 108/300... 判别器损失: 1.0210(判别真实的: 0.4406 + 判别生成的: 0.5803)... 生成器损失: 1.3663
# Epoch 109/300... 判别器损失: 1.1017(判别真实的: 0.6132 + 判别生成的: 0.4885)... 生成器损失: 1.4608
# Epoch 110/300... 判别器损失: 1.3222(判别真实的: 0.6157 + 判别生成的: 0.7065)... 生成器损失: 1.2455
# Epoch 111/300... 判别器损失: 1.0570(判别真实的: 0.4460 + 判别生成的: 0.6111)... 生成器损失: 1.3001
# Epoch 112/300... 判别器损失: 1.1883(判别真实的: 0.5765 + 判别生成的: 0.6119)... 生成器损失: 1.1869
# Epoch 113/300... 判别器损失: 0.9845(判别真实的: 0.5046 + 判别生成的: 0.4800)... 生成器损失: 1.4466
# Epoch 114/300... 判别器损失: 0.9967(判别真实的: 0.4829 + 判别生成的: 0.5138)... 生成器损失: 1.4275
# Epoch 115/300... 判别器损失: 0.9294(判别真实的: 0.4354 + 判别生成的: 0.4940)... 生成器损失: 1.3343
# Epoch 116/300... 判别器损失: 0.9559(判别真实的: 0.5867 + 判别生成的: 0.3692)... 生成器损失: 1.6681
# Epoch 117/300... 判别器损失: 0.9030(判别真实的: 0.4658 + 判别生成的: 0.4373)... 生成器损失: 1.5008
# Epoch 118/300... 判别器损失: 0.8904(判别真实的: 0.3553 + 判别生成的: 0.5352)... 生成器损失: 1.4399
# Epoch 119/300... 判别器损失: 1.0275(判别真实的: 0.4117 + 判别生成的: 0.6158)... 生成器损失: 1.1888
# Epoch 120/300... 判别器损失: 0.8435(判别真实的: 0.4885 + 判别生成的: 0.3550)... 生成器损失: 1.8166
# Epoch 121/300... 判别器损失: 1.0527(判别真实的: 0.5046 + 判别生成的: 0.5482)... 生成器损失: 1.2686
# Epoch 122/300... 判别器损失: 1.0094(判别真实的: 0.4494 + 判别生成的: 0.5600)... 生成器损失: 1.2640
# Epoch 123/300... 判别器损失: 0.8656(判别真实的: 0.4134 + 判别生成的: 0.4522)... 生成器损失: 1.5212
# Epoch 124/300... 判别器损失: 0.9663(判别真实的: 0.4333 + 判别生成的: 0.5329)... 生成器损失: 1.2822
# Epoch 125/300... 判别器损失: 0.9333(判别真实的: 0.3897 + 判别生成的: 0.5435)... 生成器损失: 1.4835
# Epoch 126/300... 判别器损失: 0.8935(判别真实的: 0.4870 + 判别生成的: 0.4065)... 生成器损失: 1.6674
# Epoch 127/300... 判别器损失: 1.0689(判别真实的: 0.4789 + 判别生成的: 0.5901)... 生成器损失: 1.3151
# Epoch 128/300... 判别器损失: 0.8909(判别真实的: 0.3249 + 判别生成的: 0.5659)... 生成器损失: 1.1807
# Epoch 129/300... 判别器损失: 1.0623(判别真实的: 0.3010 + 判别生成的: 0.7614)... 生成器损失: 0.9158
# Epoch 130/300... 判别器损失: 0.8613(判别真实的: 0.4647 + 判别生成的: 0.3966)... 生成器损失: 1.5198
# Epoch 131/300... 判别器损失: 1.2400(判别真实的: 0.4890 + 判别生成的: 0.7511)... 生成器损失: 1.1493
# Epoch 132/300... 判别器损失: 0.9010(判别真实的: 0.5725 + 判别生成的: 0.3286)... 生成器损失: 1.8184
# Epoch 133/300... 判别器损失: 0.9447(判别真实的: 0.5908 + 判别生成的: 0.3539)... 生成器损失: 1.7554
# Epoch 134/300... 判别器损失: 0.8822(判别真实的: 0.3778 + 判别生成的: 0.5044)... 生成器损失: 1.4031
# Epoch 135/300... 判别器损失: 1.1030(判别真实的: 0.5227 + 判别生成的: 0.5803)... 生成器损失: 1.3873
# Epoch 136/300... 判别器损失: 0.9377(判别真实的: 0.5409 + 判别生成的: 0.3968)... 生成器损失: 1.4501
# Epoch 137/300... 判别器损失: 1.0901(判别真实的: 0.5510 + 判别生成的: 0.5391)... 生成器损失: 1.5955
# Epoch 138/300... 判别器损失: 0.7615(判别真实的: 0.3304 + 判别生成的: 0.4311)... 生成器损失: 1.4035
# Epoch 139/300... 判别器损失: 1.1050(判别真实的: 0.7844 + 判别生成的: 0.3206)... 生成器损失: 1.9961
# Epoch 140/300... 判别器损失: 0.8434(判别真实的: 0.4892 + 判别生成的: 0.3543)... 生成器损失: 1.8239
# Epoch 141/300... 判别器损失: 0.9301(判别真实的: 0.4739 + 判别生成的: 0.4562)... 生成器损失: 1.6089
# Epoch 142/300... 判别器损失: 0.8900(判别真实的: 0.5377 + 判别生成的: 0.3522)... 生成器损失: 1.9503
# Epoch 143/300... 判别器损失: 1.0589(判别真实的: 0.4541 + 判别生成的: 0.6048)... 生成器损失: 1.1514
# Epoch 144/300... 判别器损失: 0.9737(判别真实的: 0.5858 + 判别生成的: 0.3879)... 生成器损失: 1.8251
# Epoch 145/300... 判别器损失: 0.8830(判别真实的: 0.4087 + 判别生成的: 0.4743)... 生成器损失: 1.4895
# Epoch 146/300... 判别器损失: 1.0069(判别真实的: 0.5235 + 判别生成的: 0.4834)... 生成器损失: 1.5199
# Epoch 147/300... 判别器损失: 1.1368(判别真实的: 0.6343 + 判别生成的: 0.5025)... 生成器损失: 1.4961
# Epoch 148/300... 判别器损失: 1.0164(判别真实的: 0.6306 + 判别生成的: 0.3858)... 生成器损失: 1.6220
# Epoch 149/300... 判别器损失: 0.9504(判别真实的: 0.3424 + 判别生成的: 0.6080)... 生成器损失: 1.1981
# Epoch 150/300... 判别器损失: 1.0341(判别真实的: 0.5734 + 判别生成的: 0.4607)... 生成器损失: 1.5166
# Epoch 151/300... 判别器损失: 1.0657(判别真实的: 0.5636 + 判别生成的: 0.5021)... 生成器损失: 1.6041
# Epoch 152/300... 判别器损失: 0.8334(判别真实的: 0.4422 + 判别生成的: 0.3912)... 生成器损失: 1.5912
# Epoch 153/300... 判别器损失: 1.1126(判别真实的: 0.6099 + 判别生成的: 0.5026)... 生成器损失: 1.5608
# Epoch 154/300... 判别器损失: 0.8067(判别真实的: 0.3477 + 判别生成的: 0.4590)... 生成器损失: 1.7114
# Epoch 155/300... 判别器损失: 0.9452(判别真实的: 0.5024 + 判别生成的: 0.4429)... 生成器损失: 1.5256
# Epoch 156/300... 判别器损失: 1.1353(判别真实的: 0.6570 + 判别生成的: 0.4783)... 生成器损失: 1.6095
# Epoch 157/300... 判别器损失: 1.0017(判别真实的: 0.4634 + 判别生成的: 0.5383)... 生成器损失: 1.5671
# Epoch 158/300... 判别器损失: 0.8890(判别真实的: 0.3239 + 判别生成的: 0.5651)... 生成器损失: 1.2251
# Epoch 159/300... 判别器损失: 0.6979(判别真实的: 0.3260 + 判别生成的: 0.3719)... 生成器损失: 1.6583
# Epoch 160/300... 判别器损失: 1.0711(判别真实的: 0.6867 + 判别生成的: 0.3843)... 生成器损失: 1.8754
# Epoch 161/300... 判别器损失: 1.0678(判别真实的: 0.5301 + 判别生成的: 0.5376)... 生成器损失: 1.5264
# Epoch 162/300... 判别器损失: 0.8222(判别真实的: 0.4730 + 判别生成的: 0.3492)... 生成器损失: 1.7357
# Epoch 163/300... 判别器损失: 0.8753(判别真实的: 0.5093 + 判别生成的: 0.3660)... 生成器损失: 1.6599
# Epoch 164/300... 判别器损失: 1.0412(判别真实的: 0.5194 + 判别生成的: 0.5217)... 生成器损失: 1.4158
# Epoch 165/300... 判别器损失: 1.0983(判别真实的: 0.6043 + 判别生成的: 0.4940)... 生成器损失: 1.4477
# Epoch 166/300... 判别器损失: 0.9362(判别真实的: 0.3940 + 判别生成的: 0.5422)... 生成器损失: 1.3613
# Epoch 167/300... 判别器损失: 0.9471(判别真实的: 0.4206 + 判别生成的: 0.5265)... 生成器损失: 1.3326
# Epoch 168/300... 判别器损失: 1.1073(判别真实的: 0.3632 + 判别生成的: 0.7441)... 生成器损失: 1.0684
# Epoch 169/300... 判别器损失: 0.9747(判别真实的: 0.3797 + 判别生成的: 0.5950)... 生成器损失: 1.3012
# Epoch 170/300... 判别器损失: 0.8949(判别真实的: 0.3958 + 判别生成的: 0.4990)... 生成器损失: 1.4534
# Epoch 171/300... 判别器损失: 1.0643(判别真实的: 0.4927 + 判别生成的: 0.5715)... 生成器损失: 1.2534
# Epoch 172/300... 判别器损失: 0.9528(判别真实的: 0.4387 + 判别生成的: 0.5141)... 生成器损失: 1.5276
# Epoch 173/300... 判别器损失: 1.0452(判别真实的: 0.4003 + 判别生成的: 0.6450)... 生成器损失: 1.4052
# Epoch 174/300... 判别器损失: 0.8991(判别真实的: 0.4197 + 判别生成的: 0.4794)... 生成器损失: 1.4982
# Epoch 175/300... 判别器损失: 0.8502(判别真实的: 0.3249 + 判别生成的: 0.5253)... 生成器损失: 1.3752
# Epoch 176/300... 判别器损失: 0.9864(判别真实的: 0.5069 + 判别生成的: 0.4795)... 生成器损失: 1.5411
# Epoch 177/300... 判别器损失: 1.0795(判别真实的: 0.6637 + 判别生成的: 0.4158)... 生成器损失: 1.6953
# Epoch 178/300... 判别器损失: 0.9118(判别真实的: 0.4855 + 判别生成的: 0.4263)... 生成器损失: 1.5935
# Epoch 179/300... 判别器损失: 0.9273(判别真实的: 0.6772 + 判别生成的: 0.2501)... 生成器损失: 2.1351
# Epoch 180/300... 判别器损失: 0.9676(判别真实的: 0.5436 + 判别生成的: 0.4240)... 生成器损失: 1.7305
# Epoch 181/300... 判别器损失: 0.9975(判别真实的: 0.4170 + 判别生成的: 0.5804)... 生成器损失: 1.2864
# Epoch 182/300... 判别器损失: 0.7705(判别真实的: 0.3148 + 判别生成的: 0.4557)... 生成器损失: 1.6470
# Epoch 183/300... 判别器损失: 1.0750(判别真实的: 0.6089 + 判别生成的: 0.4661)... 生成器损失: 1.4676
# Epoch 184/300... 判别器损失: 1.0130(判别真实的: 0.4795 + 判别生成的: 0.5335)... 生成器损失: 1.5907
# Epoch 185/300... 判别器损失: 0.8533(判别真实的: 0.4422 + 判别生成的: 0.4111)... 生成器损失: 1.9368
# Epoch 186/300... 判别器损失: 0.8886(判别真实的: 0.5515 + 判别生成的: 0.3371)... 生成器损失: 1.8722
# Epoch 187/300... 判别器损失: 1.0390(判别真实的: 0.4232 + 判别生成的: 0.6158)... 生成器损失: 1.4977
# Epoch 188/300... 判别器损失: 0.9905(判别真实的: 0.5060 + 判别生成的: 0.4845)... 生成器损失: 1.6291
# Epoch 189/300... 判别器损失: 1.0880(判别真实的: 0.3889 + 判别生成的: 0.6990)... 生成器损失: 1.3088
# Epoch 190/300... 判别器损失: 0.9360(判别真实的: 0.4916 + 判别生成的: 0.4444)... 生成器损失: 1.5274
# Epoch 191/300... 判别器损失: 1.0300(判别真实的: 0.5409 + 判别生成的: 0.4891)... 生成器损失: 1.5146
# Epoch 192/300... 判别器损失: 0.9286(判别真实的: 0.4187 + 判别生成的: 0.5099)... 生成器损失: 1.3798
# Epoch 193/300... 判别器损失: 0.8535(判别真实的: 0.4422 + 判别生成的: 0.4114)... 生成器损失: 1.8028
# Epoch 194/300... 判别器损失: 0.9983(判别真实的: 0.5703 + 判别生成的: 0.4280)... 生成器损失: 1.5788
# Epoch 195/300... 判别器损失: 0.7998(判别真实的: 0.3391 + 判别生成的: 0.4607)... 生成器损失: 1.4579
# Epoch 196/300... 判别器损失: 0.8031(判别真实的: 0.4432 + 判别生成的: 0.3599)... 生成器损失: 1.7367
# Epoch 197/300... 判别器损失: 0.9075(判别真实的: 0.4502 + 判别生成的: 0.4573)... 生成器损失: 1.5521
# Epoch 198/300... 判别器损失: 1.0365(判别真实的: 0.5880 + 判别生成的: 0.4486)... 生成器损失: 1.5283
# Epoch 199/300... 判别器损失: 0.8985(判别真实的: 0.6457 + 判别生成的: 0.2528)... 生成器损失: 2.3191
# Epoch 200/300... 判别器损失: 1.0008(判别真实的: 0.4211 + 判别生成的: 0.5797)... 生成器损失: 1.3483
# Epoch 201/300... 判别器损失: 0.8856(判别真实的: 0.3765 + 判别生成的: 0.5091)... 生成器损失: 1.4542
# Epoch 202/300... 判别器损失: 0.8922(判别真实的: 0.4619 + 判别生成的: 0.4303)... 生成器损失: 1.6744
# Epoch 203/300... 判别器损失: 1.0540(判别真实的: 0.5730 + 判别生成的: 0.4810)... 生成器损失: 1.5603
# Epoch 204/300... 判别器损失: 0.9893(判别真实的: 0.5652 + 判别生成的: 0.4241)... 生成器损失: 1.7085
# Epoch 205/300... 判别器损失: 0.8989(判别真实的: 0.4541 + 判别生成的: 0.4448)... 生成器损失: 1.5151
# Epoch 206/300... 判别器损失: 1.1211(判别真实的: 0.5116 + 判别生成的: 0.6094)... 生成器损失: 1.4291
# Epoch 207/300... 判别器损失: 0.7287(判别真实的: 0.4262 + 判别生成的: 0.3024)... 生成器损失: 2.2066
# Epoch 208/300... 判别器损失: 0.8519(判别真实的: 0.4883 + 判别生成的: 0.3636)... 生成器损失: 1.7615
# Epoch 209/300... 判别器损失: 0.8524(判别真实的: 0.3797 + 判别生成的: 0.4727)... 生成器损失: 1.4527
# Epoch 210/300... 判别器损失: 0.9087(判别真实的: 0.5427 + 判别生成的: 0.3660)... 生成器损失: 1.6399
# Epoch 211/300... 判别器损失: 1.0431(判别真实的: 0.6707 + 判别生成的: 0.3724)... 生成器损失: 1.6975
# Epoch 212/300... 判别器损失: 1.1982(判别真实的: 0.5590 + 判别生成的: 0.6392)... 生成器损失: 1.3596
# Epoch 213/300... 判别器损失: 1.0800(判别真实的: 0.5388 + 判别生成的: 0.5412)... 生成器损失: 1.5692
# Epoch 214/300... 判别器损失: 1.0149(判别真实的: 0.4270 + 判别生成的: 0.5879)... 生成器损失: 1.4849
# Epoch 215/300... 判别器损失: 0.9650(判别真实的: 0.2848 + 判别生成的: 0.6802)... 生成器损失: 1.2007
# Epoch 216/300... 判别器损失: 1.0271(判别真实的: 0.5975 + 判别生成的: 0.4296)... 生成器损失: 1.6694
# Epoch 217/300... 判别器损失: 0.9884(判别真实的: 0.4923 + 判别生成的: 0.4961)... 生成器损失: 1.4726
# Epoch 218/300... 判别器损失: 0.7646(判别真实的: 0.3483 + 判别生成的: 0.4163)... 生成器损失: 1.7724
# Epoch 219/300... 判别器损失: 0.8142(判别真实的: 0.3452 + 判别生成的: 0.4690)... 生成器损失: 1.5448
# Epoch 220/300... 判别器损失: 1.0339(判别真实的: 0.5496 + 判别生成的: 0.4844)... 生成器损失: 1.5567
# Epoch 221/300... 判别器损失: 0.8072(判别真实的: 0.4410 + 判别生成的: 0.3662)... 生成器损失: 1.7044
# Epoch 222/300... 判别器损失: 0.8702(判别真实的: 0.4901 + 判别生成的: 0.3801)... 生成器损失: 1.7054
# Epoch 223/300... 判别器损失: 0.8661(判别真实的: 0.4887 + 判别生成的: 0.3774)... 生成器损失: 1.7043
# Epoch 224/300... 判别器损失: 0.8495(判别真实的: 0.5089 + 判别生成的: 0.3407)... 生成器损失: 2.0188
# Epoch 225/300... 判别器损失: 1.0593(判别真实的: 0.4933 + 判别生成的: 0.5660)... 生成器损失: 1.5801
# Epoch 226/300... 判别器损失: 0.9317(判别真实的: 0.6166 + 判别生成的: 0.3150)... 生成器损失: 2.1065
# Epoch 227/300... 判别器损失: 0.9569(判别真实的: 0.4326 + 判别生成的: 0.5242)... 生成器损失: 1.6697
# Epoch 228/300... 判别器损失: 0.8771(判别真实的: 0.5699 + 判别生成的: 0.3072)... 生成器损失: 1.9140
# Epoch 229/300... 判别器损失: 0.8705(判别真实的: 0.4733 + 判别生成的: 0.3971)... 生成器损失: 1.5219
# Epoch 230/300... 判别器损失: 1.0049(判别真实的: 0.6467 + 判别生成的: 0.3582)... 生成器损失: 2.0464
# Epoch 231/300... 判别器损失: 1.0037(判别真实的: 0.5388 + 判别生成的: 0.4648)... 生成器损失: 1.3983
# Epoch 232/300... 判别器损失: 0.9327(判别真实的: 0.5857 + 判别生成的: 0.3470)... 生成器损失: 2.0818
# Epoch 233/300... 判别器损失: 1.2479(判别真实的: 0.8428 + 判别生成的: 0.4051)... 生成器损失: 1.9620
# Epoch 234/300... 判别器损失: 1.0135(判别真实的: 0.4109 + 判别生成的: 0.6026)... 生成器损失: 1.3794
# Epoch 235/300... 判别器损失: 0.9346(判别真实的: 0.6207 + 判别生成的: 0.3139)... 生成器损失: 2.0963
# Epoch 236/300... 判别器损失: 0.7778(判别真实的: 0.3923 + 判别生成的: 0.3855)... 生成器损失: 1.6474
# Epoch 237/300... 判别器损失: 0.8450(判别真实的: 0.3969 + 判别生成的: 0.4481)... 生成器损失: 1.7702
# Epoch 238/300... 判别器损失: 1.1946(判别真实的: 0.5922 + 判别生成的: 0.6024)... 生成器损失: 1.4689
# Epoch 239/300... 判别器损失: 0.9097(判别真实的: 0.5183 + 判别生成的: 0.3914)... 生成器损失: 1.7729
# Epoch 240/300... 判别器损失: 0.9784(判别真实的: 0.5190 + 判别生成的: 0.4594)... 生成器损失: 1.5587
# Epoch 241/300... 判别器损失: 0.7948(判别真实的: 0.4284 + 判别生成的: 0.3664)... 生成器损失: 1.7627
# Epoch 242/300... 判别器损失: 1.0147(判别真实的: 0.4922 + 判别生成的: 0.5225)... 生成器损失: 1.6380
# Epoch 243/300... 判别器损失: 0.7581(判别真实的: 0.3370 + 判别生成的: 0.4211)... 生成器损失: 1.6161
# Epoch 244/300... 判别器损失: 1.1345(判别真实的: 0.5790 + 判别生成的: 0.5554)... 生成器损失: 1.5850
# Epoch 245/300... 判别器损失: 0.9122(判别真实的: 0.4619 + 判别生成的: 0.4502)... 生成器损失: 1.6644
# Epoch 246/300... 判别器损失: 1.0403(判别真实的: 0.4079 + 判别生成的: 0.6325)... 生成器损失: 1.2591
# Epoch 247/300... 判别器损失: 0.8044(判别真实的: 0.4040 + 判别生成的: 0.4004)... 生成器损失: 1.7736
# Epoch 248/300... 判别器损失: 0.9237(判别真实的: 0.4945 + 判别生成的: 0.4292)... 生成器损失: 1.6869
# Epoch 249/300... 判别器损失: 0.7543(判别真实的: 0.3906 + 判别生成的: 0.3637)... 生成器损失: 1.6843
# Epoch 250/300... 判别器损失: 0.9167(判别真实的: 0.3263 + 判别生成的: 0.5904)... 生成器损失: 1.4600
# Epoch 251/300... 判别器损失: 0.8796(判别真实的: 0.3431 + 判别生成的: 0.5365)... 生成器损失: 1.3701
# Epoch 252/300... 判别器损失: 0.8798(判别真实的: 0.4196 + 判别生成的: 0.4601)... 生成器损失: 1.4306
# Epoch 253/300... 判别器损失: 0.7794(判别真实的: 0.4534 + 判别生成的: 0.3260)... 生成器损失: 1.9039
# Epoch 254/300... 判别器损失: 0.7810(判别真实的: 0.3167 + 判别生成的: 0.4643)... 生成器损失: 1.4415
# Epoch 255/300... 判别器损失: 0.9306(判别真实的: 0.4714 + 判别生成的: 0.4592)... 生成器损失: 1.6417
# Epoch 256/300... 判别器损失: 0.7324(判别真实的: 0.3967 + 判别生成的: 0.3357)... 生成器损失: 1.7775
# Epoch 257/300... 判别器损失: 0.9270(判别真实的: 0.3475 + 判别生成的: 0.5795)... 生成器损失: 1.2891
# Epoch 258/300... 判别器损失: 0.6807(判别真实的: 0.3704 + 判别生成的: 0.3103)... 生成器损失: 1.8321
# Epoch 259/300... 判别器损失: 1.1255(判别真实的: 0.6924 + 判别生成的: 0.4331)... 生成器损失: 1.8988
# Epoch 260/300... 判别器损失: 1.0239(判别真实的: 0.3697 + 判别生成的: 0.6542)... 生成器损失: 1.5844
# Epoch 261/300... 判别器损失: 0.9075(判别真实的: 0.4504 + 判别生成的: 0.4571)... 生成器损失: 1.6877
# Epoch 262/300... 判别器损失: 0.7836(判别真实的: 0.3952 + 判别生成的: 0.3884)... 生成器损失: 1.7692
# Epoch 263/300... 判别器损失: 1.1218(判别真实的: 0.4347 + 判别生成的: 0.6871)... 生成器损失: 1.3188
# Epoch 264/300... 判别器损失: 0.8801(判别真实的: 0.6417 + 判别生成的: 0.2384)... 生成器损失: 2.1041
# Epoch 265/300... 判别器损失: 0.9071(判别真实的: 0.5064 + 判别生成的: 0.4008)... 生成器损失: 1.7738
# Epoch 266/300... 判别器损失: 0.8964(判别真实的: 0.3739 + 判别生成的: 0.5225)... 生成器损失: 1.5990
# Epoch 267/300... 判别器损失: 0.8987(判别真实的: 0.4298 + 判别生成的: 0.4689)... 生成器损失: 1.8589
# Epoch 268/300... 判别器损失: 0.9548(判别真实的: 0.4600 + 判别生成的: 0.4948)... 生成器损失: 1.6349
# Epoch 269/300... 判别器损失: 0.9650(判别真实的: 0.5403 + 判别生成的: 0.4247)... 生成器损失: 1.6212
# Epoch 270/300... 判别器损失: 0.9354(判别真实的: 0.5887 + 判别生成的: 0.3467)... 生成器损失: 1.8841
# Epoch 271/300... 判别器损失: 0.9240(判别真实的: 0.4313 + 判别生成的: 0.4926)... 生成器损失: 1.5449
# Epoch 272/300... 判别器损失: 0.8130(判别真实的: 0.3786 + 判别生成的: 0.4344)... 生成器损失: 1.6482
# Epoch 273/300... 判别器损失: 0.8757(判别真实的: 0.3959 + 判别生成的: 0.4798)... 生成器损失: 1.6065
# Epoch 274/300... 判别器损失: 0.7807(判别真实的: 0.3644 + 判别生成的: 0.4163)... 生成器损失: 1.9100
# Epoch 275/300... 判别器损失: 0.9661(判别真实的: 0.5176 + 判别生成的: 0.4485)... 生成器损失: 1.6436
# Epoch 276/300... 判别器损失: 1.0624(判别真实的: 0.3887 + 判别生成的: 0.6737)... 生成器损失: 1.3604
# Epoch 277/300... 判别器损失: 0.7951(判别真实的: 0.3617 + 判别生成的: 0.4334)... 生成器损失: 1.8505
# Epoch 278/300... 判别器损失: 1.0289(判别真实的: 0.5459 + 判别生成的: 0.4829)... 生成器损失: 1.7023
# Epoch 279/300... 判别器损失: 0.9947(判别真实的: 0.3986 + 判别生成的: 0.5962)... 生成器损失: 1.3060
# Epoch 280/300... 判别器损失: 1.0639(判别真实的: 0.6282 + 判别生成的: 0.4357)... 生成器损失: 1.7196
# Epoch 281/300... 判别器损失: 0.9332(判别真实的: 0.4773 + 判别生成的: 0.4559)... 生成器损失: 1.4851
# Epoch 282/300... 判别器损失: 0.9786(判别真实的: 0.4671 + 判别生成的: 0.5116)... 生成器损失: 1.4744
# Epoch 283/300... 判别器损失: 0.9227(判别真实的: 0.5072 + 判别生成的: 0.4155)... 生成器损失: 1.7288
# Epoch 284/300... 判别器损失: 0.9140(判别真实的: 0.4287 + 判别生成的: 0.4854)... 生成器损失: 1.5651
# Epoch 285/300... 判别器损失: 0.8635(判别真实的: 0.3960 + 判别生成的: 0.4675)... 生成器损失: 1.6526
# Epoch 286/300... 判别器损失: 0.9730(判别真实的: 0.4602 + 判别生成的: 0.5128)... 生成器损失: 1.4513
# Epoch 287/300... 判别器损失: 0.8956(判别真实的: 0.4043 + 判别生成的: 0.4914)... 生成器损失: 1.3504
# Epoch 288/300... 判别器损失: 0.8087(判别真实的: 0.3460 + 判别生成的: 0.4627)... 生成器损失: 1.6121
# Epoch 289/300... 判别器损失: 0.7908(判别真实的: 0.4397 + 判别生成的: 0.3511)... 生成器损失: 1.7199
# Epoch 290/300... 判别器损失: 1.0047(判别真实的: 0.6696 + 判别生成的: 0.3351)... 生成器损失: 2.0345
# Epoch 291/300... 判别器损失: 0.8142(判别真实的: 0.5007 + 判别生成的: 0.3135)... 生成器损失: 2.0580
# Epoch 292/300... 判别器损失: 0.8190(判别真实的: 0.3912 + 判别生成的: 0.4278)... 生成器损失: 1.8180
# Epoch 293/300... 判别器损失: 0.9762(判别真实的: 0.5258 + 判别生成的: 0.4504)... 生成器损失: 1.8091
# Epoch 294/300... 判别器损失: 0.7682(判别真实的: 0.3307 + 判别生成的: 0.4376)... 生成器损失: 1.7493
# Epoch 295/300... 判别器损失: 0.8621(判别真实的: 0.4000 + 判别生成的: 0.4621)... 生成器损失: 1.6711
# Epoch 296/300... 判别器损失: 0.8977(判别真实的: 0.5024 + 判别生成的: 0.3953)... 生成器损失: 1.7367
# Epoch 297/300... 判别器损失: 0.7892(判别真实的: 0.3642 + 判别生成的: 0.4250)... 生成器损失: 1.6657
# Epoch 298/300... 判别器损失: 0.7991(判别真实的: 0.3468 + 判别生成的: 0.4523)... 生成器损失: 1.5176
# Epoch 299/300... 判别器损失: 1.0480(判别真实的: 0.5507 + 判别生成的: 0.4973)... 生成器损失: 1.4574
# Epoch 300/300... 判别器损失: 0.9445(判别真实的: 0.4906 + 判别生成的: 0.4539)... 生成器损失: 1.6833

# %% [markdown]
# # loss迭代曲线

# %%
fig, ax = plt.subplots(figsize=(20,7))
losses = np.array(losses)
plt.plot(losses.T[0], label='判别器总损失')
plt.plot(losses.T[1], label='判别真实损失')
plt.plot(losses.T[2], label='判别生成损失')
plt.plot(losses.T[3], label='生成器损失')
plt.title("对抗生成网络")
ax.set_xlabel('epoch')
plt.legend()

# %% [markdown]
# # 生成结果

# %%
# Load samples from generator taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pickle.load(f)

# %%
#samples是保存的结果 epoch是第多少次迭代
def view_samples(epoch, samples):
    
    fig, axes = plt.subplots(figsize=(7,7), nrows=5, ncols=5, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch][1]): # 这里samples[epoch][1]代表生成的图像结果，而[0]代表对应的logits
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')
    
    return fig, axes

# %%
_ = view_samples(-1, samples) # 显示最终的生成结果

# %% [markdown]
# # 显示整个生成过程图片

# %%
# 指定要查看的轮次
epoch_idx = [10, 30, 60, 90, 120, 150, 180, 210, 240, 290] 
show_imgs = []
for i in epoch_idx:
    show_imgs.append(samples[i][1])

# %%
# 指定图片形状
rows, cols = 10, 25
fig, axes = plt.subplots(figsize=(30,12), nrows=rows, ncols=cols, sharex=True, sharey=True)

idx = range(0, epochs, int(epochs/rows))

for sample, ax_row in zip(show_imgs, axes):
    for img, ax in zip(sample[::int(len(sample)/cols)], ax_row):
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

# %% [markdown]
# # 生成新的图片

# %%
# 加载我们的生成器变量
saver = tf.train.Saver(var_list=g_vars)
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    sample_noise = np.random.uniform(-1, 1, size=(25, noise_size))
    gen_samples = sess.run(get_generator(noise_img, g_units, img_size, reuse=True),
                           feed_dict={noise_img: sample_noise})
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\generator.ckpt

# %%
_ = view_samples(0, [gen_samples])
